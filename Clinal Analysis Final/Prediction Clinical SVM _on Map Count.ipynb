# %%
import pandas as pd
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
# dataset=pd.read_csv('chosen_columns_clinical1.csv')
dataset=pd.read_csv('Clinical Dataset_ Map.csv')

# %%
dataset.head()
# Out:
#    abs_lymph_7_cat  Acuity_max  Acuity_7  crp_3_cat  abs_mono_7_cat  \
# 0               -1           3         5          1              -1
# 1               -1           3         5          2              -1
# 2               -1           3         5          3              -1
# 3               -1           3         5          2              -1
# 4                5           3         3          5               3
#
#    abs_lymph_3_cat  abs_neut_7_cat  Age_cat  abs_neut_3_cat  creat_3_cat  \
# 0                4              -1        1               2            1
# 1                4              -1        2               2            1
# 2                4              -1        3               3            2
# 3                4              -1        1               3            1
# 4                5               3        3               3            1
#
#    ddimer_7_cat  Acuity_0  creat_0_cat  crp_0_cat  ddimer_0_cat  crp_7_cat  \
# 0            -1         3            2          1             1         -1
# 1            -1         3            2          3             2         -1
# 2            -1         3            2          4             3         -1
# 3            -1         3            2          1             2         -1
# 4             4         3            2          4             3          4
#
#    ldh_0_cat  creat_7_cat  BMI_cat  Class Label
# 0          2           -1        4            0
# 1          2           -1        2            0
# 2          4           -1        4            0
# 3          2           -1        2            0
# 4          3            1        3            0

# %%
dataset.describe()
# Out:
#        abs_lymph_7_cat  Acuity_max    Acuity_7   crp_3_cat  abs_mono_7_cat  \
# count       384.000000  384.000000  384.000000  384.000000      384.000000
# mean          0.875000    2.825521    3.653646    1.606771        0.893229
# std           2.185879    1.075856    1.366262    2.385565        2.214728
# min          -1.000000    1.000000    1.000000   -1.000000       -1.000000
# 25%          -1.000000    2.000000    2.000000   -1.000000       -1.000000
# 50%          -1.000000    3.000000    4.000000    2.000000       -1.000000
# 75%           3.000000    3.000000    5.000000    4.000000        3.000000
# max           5.000000    5.000000    5.000000    5.000000        5.000000
#
#        abs_lymph_3_cat  abs_neut_7_cat     Age_cat  abs_neut_3_cat  \
# count       384.000000      384.000000  384.000000      384.000000
# mean          1.736979        0.882812    3.218750        1.778646
# std           1.925800        2.101676    1.206623        1.865017
# min          -1.000000       -1.000000    1.000000       -1.000000
# 25%          -1.000000       -1.000000    2.000000       -1.000000
# 50%           2.000000       -1.000000    3.000000        2.000000
# 75%           3.000000        3.000000    4.000000        3.000000
# max           5.000000        5.000000    5.000000        5.000000
#
#        creat_3_cat  ddimer_7_cat    Acuity_0  creat_0_cat   crp_0_cat  \
# count   384.000000    384.000000  384.000000   384.000000  384.000000
# mean      1.143229      0.533854    3.091146     2.059896    2.861979
# std       1.613522      2.207015    0.910929     1.123709    1.618823
# min      -1.000000     -1.000000    1.000000    -1.000000   -1.000000
# 25%      -1.000000     -1.000000    2.000000     1.000000    2.000000
# 50%       1.000000     -1.000000    3.000000     2.000000    3.000000
# 75%       2.000000      3.000000    4.000000     2.000000    4.000000
# max       5.000000      5.000000    5.000000     5.000000    5.000000
#
#        ddimer_0_cat   crp_7_cat   ldh_0_cat  creat_7_cat     BMI_cat  \
# count    384.000000  384.000000  384.000000   384.000000  384.000000
# mean       2.463542    0.580729    2.710938     0.539062    2.479167
# std        1.466323    2.206978    1.523458     1.769641    1.151493
# min       -1.000000   -1.000000   -1.000000    -1.000000    0.000000
# 25%        2.000000   -1.000000    2.000000    -1.000000    2.000000
# 50%        2.000000   -1.000000    3.000000    -1.000000    2.000000
# 75%        3.000000    2.000000    4.000000     2.000000    3.000000
# max        5.000000    5.000000    5.000000     5.000000    5.000000
#
#        Class Label
# count   384.000000
# mean      0.127604
# std       0.334084
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
X=dataset.drop(columns='Class Label',axis=1)
Y=dataset['Class Label']

# %%
X
# Out:
#      abs_lymph_7_cat  Acuity_max  Acuity_7  crp_3_cat  abs_mono_7_cat  \
# 0                 -1           3         5          1              -1
# 1                 -1           3         5          2              -1
# 2                 -1           3         5          3              -1
# 3                 -1           3         5          2              -1
# 4                  5           3         3          5               3
# ..               ...         ...       ...        ...             ...
# 379                3           1         2          5               4
# 380                2           1         2          5               1
# 381                3           1         2          4               2
# 382               -1           1         1         -1              -1
# 383               -1           1         1          4              -1
#
#      abs_lymph_3_cat  abs_neut_7_cat  Age_cat  abs_neut_3_cat  creat_3_cat  \
# 0                  4              -1        1               2            1
# 1                  4              -1        2               2            1
# 2                  4              -1        3               3            2
# 3                  4              -1        1               3            1
# 4                  5               3        3               3            1
# ..               ...             ...      ...             ...          ...
# 379                4               3        3               4            3
# 380                2               3        4               4            2
# 381                4               3        4               2            3
# 382               -1              -1        5              -1           -1
# 383                2              -1        5               3            1
#
#      ddimer_7_cat  Acuity_0  creat_0_cat  crp_0_cat  ddimer_0_cat  crp_7_cat  \
# 0              -1         3            2          1             1         -1
# 1              -1         3            2          3             2         -1
# 2              -1         3            2          4             3         -1
# 3              -1         3            2          1             2         -1
# 4               4         3            2          4             3          4
# ..            ...       ...          ...        ...           ...        ...
# 379             4         2            3          3             4          5
# 380             5         3            3          5             3          4
# 381             2         2            3          5             4          4
# 382            -1         3            5          4             5         -1
# 383            -1         2            1          5             3         -1
#
#      ldh_0_cat  creat_7_cat  BMI_cat
# 0            2           -1        4
# 1            2           -1        2
# 2            4           -1        4
# 3            2           -1        2
# 4            3            1        3
# ..         ...          ...      ...
# 379          5            3        2
# 380          3            3        2
# 381          4            1        3
# 382          2           -1        2
# 383          5           -1        2
#
# [384 rows x 19 columns]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 379    1
# 380    1
# 381    1
# 382    1
# 383    1
# Name: Class Label, Length: 384, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y,random_state=42)

# %%
classifier = svm.SVC()

# %%
classifier.fit(X_train,y_train)
# Out:
# SVC()

# %%
X_train_prediction=classifier.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction, y_train)

# %%
print("Accuracy on training data",training_data_accuracy)
# Out:
# Accuracy on training data 0.9409722222222222

# %%
X_test_prediction=classifier.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction, y_test)

# %%
print("Accuracy on test data",test_data_accuracy)
# Out:
# Accuracy on test data 0.9479166666666666
