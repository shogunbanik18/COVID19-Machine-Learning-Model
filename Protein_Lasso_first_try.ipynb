# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV,train_test_split
from sklearn.datasets import load_diabetes

# %%
#Protein_final_utf_8.csv

# %%
dataset = pd.read_csv('Protein_final_ut.csv',
                 lineterminator='\n')

# %%
dataset.head()
# Out:
#   Patients ID  A1E959  A1L4H1  A4D1B5  A6NI73  B1AKI9  NTproBNP  O00161  \
# 0        1_D0 -0.4919 -2.0764 -4.1174 -1.6798 -1.6368   -2.9075  3.2226
# 1       10_D0 -0.4128 -2.5055 -4.2090 -2.1186 -2.1341   -2.1834  2.3743
# 2      100_D0 -0.1184 -2.1845 -4.7553 -1.0313 -2.4404   -2.3786  2.8104
# 3      101_D0  2.3431 -1.9234 -4.1818 -1.0012 -3.0546   -1.6429  1.4504
# 4      103_D0 -0.4058 -1.8440 -4.1875 -1.9196 -2.4053   -2.1893  1.5982
#
#    O00175  O00182  ...  Q9Y662  Q9Y680  Q9Y6A5  Q9Y6D9  Q9Y6E0  Q9Y6K9  \
# 0 -4.9658 -0.5558  ... -1.7002  0.1028  1.4372 -1.2237  0.0942  3.1638
# 1 -3.5027 -0.9061  ... -1.4034  0.0871  1.5215 -0.7514  0.3801  2.7710
# 2 -5.8802  0.0117  ...  0.0634  0.6548  1.3863  0.6855  0.7598  3.3714
# 3 -4.5658 -0.1437  ... -0.7388  1.7710  0.5739  0.5000  3.9538  1.6872
# 4 -1.2853 -1.9186  ... -1.6360  1.0028  0.1051 -1.8314  0.5992  1.6747
#
#    Q9Y6N7  Q9Y6Q6  Q9Y6Y9  Class Label\r
# 0 -2.5676 -2.5675 -1.0704              0
# ...

# %%
dataset.shape
# Out:
# (344, 1465)

# %%
dataset.describe()
# Out:
#            A1E959      A1L4H1      A4D1B5      A6NI73      B1AKI9    NTproBNP  \
# count  344.000000  344.000000  344.000000  344.000000  344.000000  344.000000
# mean    -0.470059   -1.813984   -4.477865   -1.044711   -2.082938    0.060057
# std      0.538593    0.540712    0.473263    0.596265    0.746470    2.319700
# min     -1.635500   -3.676900   -5.401600   -2.609700   -3.629900   -3.201900
# 25%     -0.767250   -2.164625   -4.723800   -1.406675   -2.582150   -1.598475
# 50%     -0.535650   -1.807250   -4.525300   -1.059100   -2.141750   -0.701850
# 75%     -0.267550   -1.484450   -4.358050   -0.688600   -1.658950    1.333775
# max      4.745300    0.122400   -0.061900    1.134400    0.775500    8.916200
#
#            O00161      O00175      O00182      O00186  ...      Q9Y662  \
# count  344.000000  344.000000  344.000000  344.000000  ...  344.000000
# mean     1.713144   -3.391276    0.099004    0.473133  ...   -1.149020
# ...

# %%
X=dataset.drop(columns='Class Label\r',axis=1)
y=dataset['Class Label\r']

# %%
print(X)
# Out:
#     Patients ID  A1E959  A1L4H1  A4D1B5  A6NI73  B1AKI9  NTproBNP  O00161  \
# 0          1_D0 -0.4919 -2.0764 -4.1174 -1.6798 -1.6368   -2.9075  3.2226
# 1         10_D0 -0.4128 -2.5055 -4.2090 -2.1186 -2.1341   -2.1834  2.3743
# 2        100_D0 -0.1184 -2.1845 -4.7553 -1.0313 -2.4404   -2.3786  2.8104
# 3        101_D0  2.3431 -1.9234 -4.1818 -1.0012 -3.0546   -1.6429  1.4504
# 4        103_D0 -0.4058 -1.8440 -4.1875 -1.9196 -2.4053   -2.1893  1.5982
# ..          ...     ...     ...     ...     ...     ...       ...     ...
# 339       45_D0 -0.2350 -1.1699 -4.8938 -0.3536 -1.5352    0.7698  2.8747
# 340       46_D0 -0.6947 -2.7393 -4.5285 -1.9382 -3.3073    3.6338  0.9896
# 341       53_D0 -0.5367 -1.9027 -4.1107 -0.7150 -2.2652   -0.6560  3.0865
# 342       56_D0  0.2077 -2.4165 -4.6623 -0.1746 -2.3921    2.9758  0.2672
# 343       61_D0 -0.0601 -1.3297 -4.6848 -0.0891 -0.9847    5.0848  2.8900
#
#      O00175  O00182  ...  Q9Y653  Q9Y662  Q9Y680  Q9Y6A5  Q9Y6D9  Q9Y6E0  \
# ...

# %%
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    1
# 340    1
# 341    1
# 342    1
# 343    1
# Name: Class Label\r, Length: 344, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
pipeline=Pipeline([
    ('scaler',StandardScaler()),
    ('model',Lasso())
])

# %%
search=GridSearchCV(pipeline,
                   {'model__alpha':np.arange(0.1,3,0.1)},
                    cv=5,
                    scoring='neg_mean_squared_error',
                    verbose=3
                   )

# %%
search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 29 candidates, totalling 145 fits
# [CV 1/5] END ....................model__alpha=0.1;, score=nan total time=   0.0s
# [CV 2/5] END ....................model__alpha=0.1;, score=nan total time=   0.0s
# [CV 3/5] END ....................model__alpha=0.1;, score=nan total time=   0.0s
# [CV 4/5] END ....................model__alpha=0.1;, score=nan total time=   0.0s
# [CV 5/5] END ....................model__alpha=0.1;, score=nan total time=   0.0s
# [CV 1/5] END ....................model__alpha=0.2;, score=nan total time=   0.0s
# [CV 2/5] END ....................model__alpha=0.2;, score=nan total time=   0.0s
# [CV 3/5] END ....................model__alpha=0.2;, score=nan total time=   0.0s
# C:\Users\baibh\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
# ...

# %%
search.best_params_
# Out:
# {'model__alpha': 0.1}

# %%
coefficients = search.best_estimator_.named_steps['model'].coeff_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12620/1146074540.py in <module>
# ----> 1 coefficients = search.best_estimator_.named_steps['model'].coeff_
#
# AttributeError: 'Lasso' object has no attribute 'coeff_'

# %%
print(coefficients)
# Out:
# Lasso(alpha=0.1)
