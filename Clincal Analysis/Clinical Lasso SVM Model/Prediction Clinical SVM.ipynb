# %%
import pandas as pd
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
# dataset=pd.read_csv('chosen_columns_clinical1.csv')
dataset=pd.read_csv('clinical_check10.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0  Age_cat  Acuity_0  Acuity_7  Acuity_max  ldh_0_cat  \
# 0           0        1         3         5           3          2
# 1           1        2         3         5           3          2
# 2           2        3         3         5           3          4
# 3           3        1         3         5           3          2
# 4           4        3         3         3           3          3
#
#    creat_3_cat  crp_3_cat  abs_neut_7_cat  abs_lymph_7_cat  creat_7_cat  \
# 0            1          1              -1               -1           -1
# 1            1          2              -1               -1           -1
# 2            2          3              -1               -1           -1
# 3            1          2              -1               -1           -1
# 4            1          5               3                5            1
#
#    ddimer_7_cat  Class Label
# 0            -1            0
# 1            -1            0
# 2            -1            0
# 3            -1            0
# 4             4            0

# %%
dataset.describe()
# Out:
#        Unnamed: 0     Age_cat    Acuity_0    Acuity_7  Acuity_max   ldh_0_cat  \
# count  384.000000  384.000000  384.000000  384.000000  384.000000  384.000000
# mean   191.500000    3.218750    3.091146    3.653646    2.825521    2.710938
# std    110.995495    1.206623    0.910929    1.366262    1.075856    1.523458
# min      0.000000    1.000000    1.000000    1.000000    1.000000   -1.000000
# 25%     95.750000    2.000000    2.000000    2.000000    2.000000    2.000000
# 50%    191.500000    3.000000    3.000000    4.000000    3.000000    3.000000
# 75%    287.250000    4.000000    4.000000    5.000000    3.000000    4.000000
# max    383.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#        creat_3_cat   crp_3_cat  abs_neut_7_cat  abs_lymph_7_cat  creat_7_cat  \
# count   384.000000  384.000000      384.000000       384.000000   384.000000
# mean      1.143229    1.606771        0.882812         0.875000     0.539062
# std       1.613522    2.385565        2.101676         2.185879     1.769641
# min      -1.000000   -1.000000       -1.000000        -1.000000    -1.000000
# 25%      -1.000000   -1.000000       -1.000000        -1.000000    -1.000000
# 50%       1.000000    2.000000       -1.000000        -1.000000    -1.000000
# 75%       2.000000    4.000000        3.000000         3.000000     2.000000
# max       5.000000    5.000000        5.000000         5.000000     5.000000
#
#        ddimer_7_cat  Class Label
# count    384.000000   384.000000
# mean       0.533854     0.127604
# std        2.207015     0.334084
# min       -1.000000     0.000000
# 25%       -1.000000     0.000000
# 50%       -1.000000     0.000000
# 75%        3.000000     0.000000
# max        5.000000     1.000000

# %%
X=dataset.drop(columns='Class Label',axis=1)
Y=dataset['Class Label']

# %%
X
# Out:
#      Unnamed: 0  Age_cat  Acuity_0  Acuity_7  Acuity_max  ldh_0_cat  \
# 0             0        1         3         5           3          2
# 1             1        2         3         5           3          2
# 2             2        3         3         5           3          4
# 3             3        1         3         5           3          2
# 4             4        3         3         3           3          3
# ..          ...      ...       ...       ...         ...        ...
# 379         379        3         2         2           1          5
# 380         380        4         3         2           1          3
# 381         381        4         2         2           1          4
# 382         382        5         3         1           1          2
# 383         383        5         2         1           1          5
#
#      creat_3_cat  crp_3_cat  abs_neut_7_cat  abs_lymph_7_cat  creat_7_cat  \
# 0              1          1              -1               -1           -1
# 1              1          2              -1               -1           -1
# 2              2          3              -1               -1           -1
# 3              1          2              -1               -1           -1
# 4              1          5               3                5            1
# ..           ...        ...             ...              ...          ...
# 379            3          5               3                3            3
# 380            2          5               3                2            3
# 381            3          4               3                3            1
# 382           -1         -1              -1               -1           -1
# 383            1          4              -1               -1           -1
#
#      ddimer_7_cat
# 0              -1
# 1              -1
# 2              -1
# 3              -1
# 4               4
# ..            ...
# 379             4
# 380             5
# 381             2
# 382            -1
# 383            -1
#
# [384 rows x 12 columns]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 379    1
# 380    1
# 381    1
# 382    1
# 383    1
# Name: Class Label, Length: 384, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y,random_state=42)

# %%
classifier = svm.SVC()

# %%
classifier.fit(X_train,y_train)
# Out:
# SVC()

# %%
X_train_prediction=classifier.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction, y_train)

# %%
print("Accuracy on training data",training_data_accuracy)
# Out:
# Accuracy on training data 0.9965277777777778

# %%
X_test_prediction=classifier.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction, y_test)

# %%
print("Accuracy on test data",test_data_accuracy)
# Out:
# Accuracy on test data 1.0
